# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime 
import numpy as np
import seaborn as sns

# %matplotlib inline

# %%
may_stationary = pd.read_pickle('../data/may_stationaryscooter_tw.pkl')
june_stationary = pd.read_pickle('../data/june_stationaryscooter_tw.pkl')
july_stationary = pd.read_pickle('../data/july_stationaryscooter_tw.pkl')

# %%
may_stationary.head(10)
# Out:
#       index         pubdatetime   latitude  longitude  \
# 0  13040512 2019-05-24 07:20:00  36.216279 -86.729816
# 1  16993465 2019-05-28 17:58:51  36.162549 -86.774197
# 2  17126263 2019-05-28 20:53:56  36.162530 -86.774246
# 3  17130115 2019-05-28 20:58:56  36.162530 -86.774246
# 4  17134009 2019-05-28 21:03:56  36.162530 -86.774246
# 5  17137902 2019-05-28 21:08:56  36.162530 -86.774246
# 6  17142018 2019-05-28 21:13:57  36.162530 -86.774246
# 7  17145815 2019-05-28 21:18:57  36.162530 -86.774246
# 8  17149849 2019-05-28 21:23:57  36.162530 -86.774246
# 9  17153683 2019-05-28 21:29:19  36.162530 -86.774246
#
#                                          sumdid  chargelevel  companyname  \
# 0  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        68.41            6
# 1  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 2  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 3  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 4  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 5  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 6  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 7  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 8  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
# 9  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619       100.00            6
#
#         dates     times  hours  latmovement  lonmovement  timeshift  duration  \
# 0  2019-05-24  07:20:00      7          0.0          0.0        NaN         0
# 1  2019-05-28  17:58:51     17          0.0          0.0   383931.0         0
# 2  2019-05-28  20:53:56     20          0.0          0.0    10505.0         0
# 3  2019-05-28  20:58:56     20          0.0          0.0      300.0         5
# 4  2019-05-28  21:03:56     21          0.0          0.0      300.0         5
# 5  2019-05-28  21:08:56     21          0.0          0.0      300.0         5
# 6  2019-05-28  21:13:57     21          0.0          0.0      301.0         5
# 7  2019-05-28  21:18:57     21          0.0          0.0      300.0         5
# 8  2019-05-28  21:23:57     21          0.0          0.0      300.0         5
# 9  2019-05-28  21:29:19     21          0.0          0.0      322.0         5
#
#    cumulative_sum
# 0               0
# 1               0
# 2               0
# 3               5
# 4              10
# 5              15
# 6              20
# 7              25
# 8              30
# 9              35

# %%
may_stationary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8755359 entries, 0 to 8755358
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   index           int64
#  1   pubdatetime     datetime64[ns]
#  2   latitude        float64
#  3   longitude       float64
#  4   sumdid          object
#  5   chargelevel     float64
#  6   companyname     int64
#  7   dates           object
#  8   times           object
#  9   hours           int64
#  10  latmovement     float64
#  11  lonmovement     float64
#  12  timeshift       float64
#  13  duration        int64
#  14  cumulative_sum  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 1002.0+ MB

# %%
june_stationary = june_stationary.reset_index()

# %%
june_stationary.head(10)
# Out:
#      index         pubdatetime   latitude  longitude  \
# 0   255360 2019-06-01 06:42:14  36.152751 -86.769299
# 1   268534 2019-06-01 07:07:15  36.152744 -86.769321
# 2   553942 2019-06-01 14:52:32  36.152765 -86.769309
# 3   558052 2019-06-01 14:57:33  36.152765 -86.769309
# 4   966392 2019-06-01 23:47:53  36.152744 -86.769319
# 5  1260373 2019-06-02 07:58:12  36.152744 -86.769320
# 6  1262822 2019-06-02 08:03:12  36.152744 -86.769320
# 7  1381090 2019-06-02 11:58:20  36.152769 -86.769299
# 8  1513178 2019-06-02 15:13:29  36.152765 -86.769290
# 9  1516722 2019-06-02 15:18:29  36.152765 -86.769290
#
#                                          sumdid  chargelevel  companyname  \
# 0  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        56.64            6
# 1  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        56.64            6
# 2  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        54.65            6
# 3  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        54.65            6
# 4  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        53.51            6
# 5  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        51.81            6
# 6  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        51.81            6
# 7  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        50.68            6
# 8  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        49.54            6
# 9  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        49.54            6
#
#         dates     times  hours  latmovement  lonmovement  timeshift  duration  \
# 0  2019-06-01  06:42:14      6          0.0          0.0        NaN         0
# 1  2019-06-01  07:07:15      7          0.0          0.0     1501.0         0
# 2  2019-06-01  14:52:32     14          0.0          0.0    27917.0         0
# 3  2019-06-01  14:57:33     14          0.0          0.0      301.0         5
# 4  2019-06-01  23:47:53     23          0.0          0.0    31820.0         0
# 5  2019-06-02  07:58:12      7          0.0          0.0    29419.0         0
# 6  2019-06-02  08:03:12      8          0.0          0.0      300.0         5
# 7  2019-06-02  11:58:20     11          0.0          0.0    14108.0         0
# 8  2019-06-02  15:13:29     15          0.0          0.0    11709.0         0
# 9  2019-06-02  15:18:29     15          0.0          0.0      300.0         5
#
#    cumulative_sum
# 0               0
# 1               0
# 2               0
# 3               5
# 4               0
# 5               0
# 6               5
# 7               0
# 8               0
# 9               5

# %%
june_stationary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14397732 entries, 255360 to 28043545
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   pubdatetime     datetime64[ns]
#  1   latitude        float64
#  2   longitude       float64
#  3   sumdid          object
#  4   chargelevel     float64
#  5   companyname     int64
#  6   dates           object
#  7   times           object
#  8   hours           int64
#  9   latmovement     float64
#  10  lonmovement     float64
#  11  timeshift       float64
#  12  duration        int64
#  13  cumulative_sum  int64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(3)
# memory usage: 1.6+ GB

# %%
july_stationary = july_stationary.reset_index()

# %%
july_stationary.head()
# Out:
#      index         pubdatetime   latitude  longitude  \
# 0  1951476 2019-07-03 05:10:54  36.164350 -86.769388
# 1  1954230 2019-07-03 05:15:54  36.164350 -86.769388
# 2  2015841 2019-07-03 07:10:58  36.164349 -86.769368
# 3  2089947 2019-07-03 09:41:02  36.164348 -86.769368
# 4  2119236 2019-07-03 10:41:04  36.164376 -86.769374
#
#                                          sumdid  chargelevel  companyname  \
# 0  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        99.49            6
# 1  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        99.49            6
# 2  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        99.49            6
# 3  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        98.93            6
# 4  Powered-017d3133-f14a-2b83-ee4f-d777e7c5b619        98.93            6
#
#         dates     times  hours  latmovement  lonmovement  timeshift  duration  \
# 0  2019-07-03  05:10:54      5          0.0          0.0        NaN         0
# 1  2019-07-03  05:15:54      5          0.0          0.0      300.0         5
# 2  2019-07-03  07:10:58      7          0.0          0.0     6904.0         0
# 3  2019-07-03  09:41:02      9          0.0          0.0     9004.0         0
# 4  2019-07-03  10:41:04     10          0.0          0.0     3602.0         0
#
#    cumulative_sum
# 0               0
# 1               5
# 2               0
# 3               0
# 4               0

# %%
july_stationary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14315678 entries, 1951476 to 25074556
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   pubdatetime     datetime64[ns]
#  1   latitude        float64
#  2   longitude       float64
#  3   sumdid          object
#  4   chargelevel     float64
#  5   companyname     int64
#  6   dates           object
#  7   times           object
#  8   hours           int64
#  9   latmovement     float64
#  10  lonmovement     float64
#  11  timeshift       float64
#  12  duration        int64
#  13  cumulative_sum  int64
# dtypes: datetime64[ns](1), float64(6), int64(4), object(3)
# memory usage: 1.6+ GB

# %% [markdown]
# They look good!  Now - How many individual scooters for each month were still for 30 mins?

# %%
may30mins = may_stationary.loc[may_stationary['cumulative_sum'] == 30]
may30mins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194117 entries, 8 to 8755135
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   index           194117 non-null  int64
#  1   pubdatetime     194117 non-null  datetime64[ns]
#  2   latitude        194117 non-null  float64
#  3   longitude       194117 non-null  float64
#  4   sumdid          194117 non-null  object
#  5   chargelevel     194114 non-null  float64
#  6   companyname     194117 non-null  int64
#  7   dates           194117 non-null  object
#  8   times           194117 non-null  object
#  9   hours           194117 non-null  int64
#  10  latmovement     194117 non-null  float64
#  11  lonmovement     194117 non-null  float64
#  12  timeshift       194117 non-null  float64
#  13  duration        194117 non-null  int64
#  14  cumulative_sum  194117 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 23.7+ MB

# %%
may30mins['sumdid'].value_counts()
# Out:
# Powered726       437
# Powered653       435
# Powered715       424
# Powered430       421
# Powered451       413
#                 ...
# Powered488AH       1
# PoweredY43Q4       1
# PoweredWT1W8       1
# PoweredG4BDM       1
# Powered575606      1
# Name: sumdid, Length: 5830, dtype: int64

# %%
may1hour = may_stationary.loc[may_stationary['cumulative_sum'] == 60]
may1hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64343 entries, 14 to 8755141
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           64343 non-null  int64
#  1   pubdatetime     64343 non-null  datetime64[ns]
#  2   latitude        64343 non-null  float64
#  3   longitude       64343 non-null  float64
#  4   sumdid          64343 non-null  object
#  5   chargelevel     64340 non-null  float64
#  6   companyname     64343 non-null  int64
#  7   dates           64343 non-null  object
#  8   times           64343 non-null  object
#  9   hours           64343 non-null  int64
#  10  latmovement     64343 non-null  float64
#  11  lonmovement     64343 non-null  float64
#  12  timeshift       64343 non-null  float64
#  13  duration        64343 non-null  int64
#  14  cumulative_sum  64343 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 7.9+ MB

# %%
may1hour['sumdid'].value_counts()
# Out:
# Powered3f0449b5-1034-5425-8dd0-f75d91d3472c    98
# Powered5a78e8cb-f1b2-567e-ad4f-840936fe1526    84
# Powereddd628ff0-83bc-56a9-878a-071fa6ca3914    82
# Poweredbdb68340-f6f5-561b-83ef-82a0c51f9630    80
# Powered703                                     75
#                                                ..
# PoweredQ9SF3                                    1
# Powered85B5Y                                    1
# PoweredDBL2I                                    1
# Powered4KX6S                                    1
# PoweredBHCHLC7NPZNBA                            1
# Name: sumdid, Length: 4673, dtype: int64

# %%
may2hour = may_stationary.loc[may_stationary['cumulative_sum'] == 120]
may2hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36192 entries, 133 to 8755153
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           36192 non-null  int64
#  1   pubdatetime     36192 non-null  datetime64[ns]
#  2   latitude        36192 non-null  float64
#  3   longitude       36192 non-null  float64
#  4   sumdid          36192 non-null  object
#  5   chargelevel     36190 non-null  float64
#  6   companyname     36192 non-null  int64
#  7   dates           36192 non-null  object
#  8   times           36192 non-null  object
#  9   hours           36192 non-null  int64
#  10  latmovement     36192 non-null  float64
#  11  lonmovement     36192 non-null  float64
#  12  timeshift       36192 non-null  float64
#  13  duration        36192 non-null  int64
#  14  cumulative_sum  36192 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 4.4+ MB

# %%
may2hour['sumdid'].value_counts()
# Out:
# Powered3f0449b5-1034-5425-8dd0-f75d91d3472c    70
# Powereda1b694a5-5fd4-5b48-b90c-db734204cc8e    56
# Powerede2cec0ed-8005-524a-928b-a47475cd76d2    56
# Powered1f24f3dd-ae95-5daf-b119-9441174e084e    53
# Poweredbdb68340-f6f5-561b-83ef-82a0c51f9630    53
#                                                ..
# PoweredTFGR2RHDFHRD3                            1
# PoweredDNCQL                                    1
# Powered6D2CNBJHGISHK                            1
# PoweredAJH3PM4JFBMGE                            1
# Powered5750098                                  1
# Name: sumdid, Length: 3108, dtype: int64

# %%
may_stationary.describe()
# Out:
#               index      latitude     longitude   chargelevel   companyname  \
# count  8.755359e+06  8.755359e+06  8.755359e+06  8.755080e+06  8.755359e+06
# mean   1.144422e+07  3.612077e+01 -8.671307e+01  5.844616e+01  3.350299e+00
# std    5.614695e+06  9.391422e-01  2.254063e+00  3.548225e+01  1.511632e+00
# min    2.329000e+03  0.000000e+00 -8.728604e+01  0.000000e+00  0.000000e+00
# 25%    7.200124e+06  3.612585e+01 -8.679104e+01  3.200000e+01  3.000000e+00
# 50%    1.207424e+07  3.615120e+01 -8.677885e+01  6.700000e+01  3.000000e+00
# 75%    1.617312e+07  3.616203e+01 -8.676290e+01  9.100000e+01  5.000000e+00
# max    2.029250e+07  3.661670e+01  0.000000e+00  1.000000e+02  6.000000e+00
#
#               hours  latmovement  lonmovement     timeshift      duration  \
# count  8.755359e+06    8755359.0    8755359.0  8.755358e+06  8.755359e+06
# mean   1.214103e+01          0.0          0.0  7.589775e-02  4.101889e+00
# std    7.014034e+00          0.0          0.0  5.088723e+04  1.919362e+00
# min    0.000000e+00          0.0          0.0 -2.677605e+06  0.000000e+00
# 25%    6.000000e+00          0.0          0.0  3.000000e+02  5.000000e+00
# 50%    1.300000e+01          0.0          0.0  3.001830e+02  5.000000e+00
# 75%    1.800000e+01          0.0          0.0  3.010000e+02  5.000000e+00
# max    2.300000e+01          0.0          0.0  2.442287e+06  5.000000e+00
#
#        cumulative_sum
# count    8.755359e+06
# mean     6.031509e+02
# std      2.194820e+03
# min      0.000000e+00
# 25%      5.000000e+00
# 50%      2.000000e+01
# 75%      1.850000e+02
# max      2.145500e+04

# %% [markdown]
# max time = 21455 mins (357 hours/15ish days)
# avg time = 603 mins (10 hours)
# mode time = 20 mins

# %%
may5hour = may_stationary.loc[may_stationary['cumulative_sum'] == 300]
may5hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11151 entries, 169 to 8755189
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           11151 non-null  int64
#  1   pubdatetime     11151 non-null  datetime64[ns]
#  2   latitude        11151 non-null  float64
#  3   longitude       11151 non-null  float64
#  4   sumdid          11151 non-null  object
#  5   chargelevel     11150 non-null  float64
#  6   companyname     11151 non-null  int64
#  7   dates           11151 non-null  object
#  8   times           11151 non-null  object
#  9   hours           11151 non-null  int64
#  10  latmovement     11151 non-null  float64
#  11  lonmovement     11151 non-null  float64
#  12  timeshift       11151 non-null  float64
#  13  duration        11151 non-null  int64
#  14  cumulative_sum  11151 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 1.4+ MB

# %%
may5hour['sumdid'].value_counts()
# Out:
# Powered63TSVEL45AYAP                           30
# PoweredBZYD3PR7EEMXK                           25
# PoweredGJXGSI4SY2PDK                           25
# PoweredAA3ZQ7IPB7GAK                           25
# Powered1181344e-4993-5ad7-9372-c4259b3a55ef    23
#                                                ..
# Powered707                                      1
# PoweredRFWYELLRTRQ2F                            1
# PoweredOPWTGXQNAXHGS                            1
# Powered262V7ZGH6DLCJ                            1
# Powered7XPHMHYXABRUR                            1
# Name: sumdid, Length: 2120, dtype: int64

# %%
may12hour = may_stationary.loc[may_stationary['cumulative_sum'] == 720]
may12hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4948 entries, 253 to 8755273
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           4948 non-null   int64
#  1   pubdatetime     4948 non-null   datetime64[ns]
#  2   latitude        4948 non-null   float64
#  3   longitude       4948 non-null   float64
#  4   sumdid          4948 non-null   object
#  5   chargelevel     4947 non-null   float64
#  6   companyname     4948 non-null   int64
#  7   dates           4948 non-null   object
#  8   times           4948 non-null   object
#  9   hours           4948 non-null   int64
#  10  latmovement     4948 non-null   float64
#  11  lonmovement     4948 non-null   float64
#  12  timeshift       4948 non-null   float64
#  13  duration        4948 non-null   int64
#  14  cumulative_sum  4948 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 618.5+ KB

# %%
may12hour['sumdid'].value_counts()
# Out:
# PoweredGJXGSI4SY2PDK                           13
# Powered63TSVEL45AYAP                           13
# PoweredEGCCBHBAK7LQE                           12
# PoweredRYBS56AVNJ675                           12
# PoweredBZYD3PR7EEMXK                           12
#                                                ..
# PoweredES6N3FBX3O436                            1
# Powered9f5743ed-7f81-539b-9e37-6503d54445d3     1
# PoweredVSQTHWFPDMTH4                            1
# PoweredJ3W3IYZKYFJ3B                            1
# PoweredQILZXUCGQ4FQ4                            1
# Name: sumdid, Length: 1288, dtype: int64

# %%
may24hour = may_stationary.loc[may_stationary['cumulative_sum'] == 1440]
may24hour.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2375 entries, 397 to 8754198
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           2375 non-null   int64
#  1   pubdatetime     2375 non-null   datetime64[ns]
#  2   latitude        2375 non-null   float64
#  3   longitude       2375 non-null   float64
#  4   sumdid          2375 non-null   object
#  5   chargelevel     2375 non-null   float64
#  6   companyname     2375 non-null   int64
#  7   dates           2375 non-null   object
#  8   times           2375 non-null   object
#  9   hours           2375 non-null   int64
#  10  latmovement     2375 non-null   float64
#  11  lonmovement     2375 non-null   float64
#  12  timeshift       2375 non-null   float64
#  13  duration        2375 non-null   int64
#  14  cumulative_sum  2375 non-null   int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 296.9+ KB

# %%
may24hour['sumdid'].value_counts()
# Out:
# PoweredRYBS56AVNJ675                           8
# Powered05fee9e1-d132-5e4f-88cd-153058d391fa    7
# PoweredGJXGSI4SY2PDK                           7
# Poweredef299f04-19d3-5f8d-83e1-4a0865149ca5    6
# Poweredb939f8fc-1de3-51dd-b945-925b04bd19d5    6
#                                               ..
# Poweredcf283f9e-5df3-5339-8a3e-21a35f6167cb    1
# Powered738305                                  1
# PoweredKLMMKZIHLRSDU                           1
# PoweredDWEQCBX3WO726                           1
# PoweredXRVNRHYGRT37Y                           1
# Name: sumdid, Length: 712, dtype: int64

# %%
may24plus = may_stationary.loc[may_stationary['cumulative_sum'] >= 1440]
may24plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 749081 entries, 397 to 8754515
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   index           749081 non-null  int64
#  1   pubdatetime     749081 non-null  datetime64[ns]
#  2   latitude        749081 non-null  float64
#  3   longitude       749081 non-null  float64
#  4   sumdid          749081 non-null  object
#  5   chargelevel     749081 non-null  float64
#  6   companyname     749081 non-null  int64
#  7   dates           749081 non-null  object
#  8   times           749081 non-null  object
#  9   hours           749081 non-null  int64
#  10  latmovement     749081 non-null  float64
#  11  lonmovement     749081 non-null  float64
#  12  timeshift       749081 non-null  float64
#  13  duration        749081 non-null  int64
#  14  cumulative_sum  749081 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 91.4+ MB

# %%
may24plus['sumdid'].value_counts()
# Out:
# Powered341                                     4902
# Powered516                                     4902
# Powered832                                     4902
# Powered593                                     4902
# Powered826                                     4902
#                                                ...
# Powered47099b12-da4d-5d9d-804c-549433311bbf       4
# Powereda8ec6f65-8c26-5ebe-91e8-9ffe03b16835       2
# Poweredd60df5ce-53ca-5ab2-8f8f-d599520795f8       2
# PoweredHTG5THJORNFOF                              1
# Powered35c3af7e-e8be-5918-934f-72629d5e3fdf       1
# Name: sumdid, Length: 712, dtype: int64

# %%
may24plus['cumulative_sum'].value_counts()
# Out:
# 1440     2375
# 1445     2373
# 1450     2371
# 1455     2369
# 1460     2044
#          ...
# 20845      55
# 21430      55
# 21330      55
# 21450      42
# 21455      42
# Name: cumulative_sum, Length: 4004, dtype: int64

# %%
may24plus_sorted = may24plus.sort_values(['cumulative_sum','companyname'], ascending = (False, True))
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141565 entries, 720461 to 7037870
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   index           141565 non-null  int64
#  1   pubdatetime     141565 non-null  datetime64[ns]
#  2   latitude        141565 non-null  float64
#  3   longitude       141565 non-null  float64
#  4   sumdid          141565 non-null  object
#  5   chargelevel     141565 non-null  float64
#  6   companyname     141565 non-null  int64
#  7   dates           141565 non-null  object
#  8   times           141565 non-null  object
#  9   hours           141565 non-null  int64
#  10  latmovement     141565 non-null  float64
#  11  lonmovement     141565 non-null  float64
#  12  timeshift       141565 non-null  float64
#  13  duration        141565 non-null  int64
#  14  cumulative_sum  141565 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 17.3+ MB

# %%
mayweekplus['sumdid'].value_counts()
# Out:
# Powered815              2276
# Powered410              2276
# Powered710              2276
# Powered731              2276
# Powered453              2276
#                         ...
# Powered5853593           221
# PoweredL3EIUVX3W33OR     195
# Powered699                94
# Powered7RULSQOA2LM2J      13
# Powered4151830             5
# Name: sumdid, Length: 75, dtype: int64

# %%
mayweekplus['companyname'].value_counts()
# Out:
# 2    134732
# 3      6607
# 4       226
# Name: companyname, dtype: int64

# %%
mayweekplus['cumulative_sum'].value_counts()
# Out:
# 10085    75
# 10080    75
# 10095    75
# 10090    75
# 10100    75
#          ..
# 20570    55
# 20390    55
# 20495    55
# 21450    42
# 21455    42
# Name: cumulative_sum, Length: 2276, dtype: int64

# %%
mayweekplus_orderly = mayweekplus.loc[mayweekplus['cumulative_sum'].isin([10080, 11520, 12960, 14400, 15840, 17280, 18720, 20160])]
mayweekplus_orderly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 509 entries, 720461 to 7037640
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           509 non-null    int64
#  1   pubdatetime     509 non-null    datetime64[ns]
#  2   latitude        509 non-null    float64
#  3   longitude       509 non-null    float64
#  4   sumdid          509 non-null    object
#  5   chargelevel     509 non-null    float64
#  6   companyname     509 non-null    int64
#  7   dates           509 non-null    object
#  8   times           509 non-null    object
#  9   hours           509 non-null    int64
#  10  latmovement     509 non-null    float64
#  11  lonmovement     509 non-null    float64
#  12  timeshift       509 non-null    float64
#  13  duration        509 non-null    int64
#  14  cumulative_sum  509 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 63.6+ KB

# %%
may5hourviz = may5hour[['sumdid','pubdatetime', 'latitude','longitude','chargelevel','companyname', 'cumulative_sum']]
may5hourviz.head()
# Out:
#                                             sumdid         pubdatetime  \
# 169   Powered-01a24436-0315-e1bb-7ce0-d081d05dff7d 2019-05-29 07:09:22
# 1835  Powered-0b4a127c-3c2a-a917-cbf4-ccb17b8604f6 2019-05-26 21:07:13
# 2777  Powered-1a8321d0-5c21-04a4-bd7d-7b96ba51f17b 2019-05-28 19:28:53
# 2987  Powered-1a8321d0-5c21-04a4-bd7d-7b96ba51f17b 2019-05-29 15:34:42
# 3217  Powered-1a8321d0-5c21-04a4-bd7d-7b96ba51f17b 2019-05-30 12:25:29
#
#        latitude  longitude  chargelevel  companyname  cumulative_sum
# 169   36.157681 -86.791208        36.49            6             300
# 1835  36.167789 -86.768577        55.50            6             300
# 2777  36.173643 -86.772373        60.33            6             300
# 2987  36.173658 -86.772352        57.49            6             300
# 3217  36.173663 -86.772361        55.50            6             300

# %%
may24hourviz = may24hour[['sumdid','pubdatetime', 'latitude','longitude','chargelevel','companyname', 'cumulative_sum']]
may24hourviz.head()
# Out:
#                                              sumdid         pubdatetime  \
# 397    Powered-01a24436-0315-e1bb-7ce0-d081d05dff7d 2019-05-30 02:10:04
# 6918   Powered-41879351-f267-1574-eb1f-5c79437c4453 2019-05-30 14:25:37
# 9834   Powered-5e26df3f-3475-f5dc-4361-86fa55423ff5 2019-05-31 06:26:19
# 11375  Powered-6c189807-63b1-0749-bc6c-90840328bc8f 2019-05-28 08:28:29
# 13049  Powered-7ed3576a-5054-84ed-41a9-4a9785ceca2d 2019-05-29 10:24:29
#
#         latitude  longitude  chargelevel  companyname  cumulative_sum
# 397    36.157681 -86.791208        34.79            6            1440
# 6918   36.158477 -86.789903        88.71            6            1440
# 9834   36.152917 -86.783645        66.00            6            1440
# 11375  36.153707 -86.784051        26.26            6            1440
# 13049  36.171223 -86.789479        88.43            6            1440

# %%
mayweekplusviz = mayweekplus[['sumdid','pubdatetime', 'latitude','longitude','chargelevel','companyname', 'cumulative_sum']]
mayweekplusviz.head()
# Out:
#             sumdid             pubdatetime   latitude  longitude  chargelevel  \
# 720461  Powered253 2019-05-20 18:52:08.743  36.121412 -86.770533         93.0
# 720462  Powered253 2019-05-20 18:57:08.857  36.121412 -86.770533         93.0
# 720463  Powered253 2019-05-20 19:02:08.937  36.121412 -86.770533         93.0
# 720464  Powered253 2019-05-20 19:07:09.117  36.121412 -86.770533         93.0
# 720465  Powered253 2019-05-20 19:12:09.190  36.121412 -86.770533         93.0
#
#         companyname  cumulative_sum
# 720461            2           10080
# 720462            2           10085
# 720463            2           10090
# 720464            2           10095
# 720465            2           10100

# %%
may24hourviz.plot(x = 'pubdatetime', y= 'chargelevel')
# Out:
# <AxesSubplot:xlabel='pubdatetime'>

# %%
may24hourviz.plot(x='chargelevel', y=('companyname'=1)
# Out:
#   File "<ipython-input-94-2d960d324a09>", line 1
#     may24hourviz.plot(x='chargelevel', y=('companyname'=1)
#                                                        ^
# SyntaxError: invalid syntax

# %%
june24plus= june_stationary.loc[june_stationary['cumulative_sum']>=1440]
june24plus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2348187 entries, 5489 to 14396581
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   index           int64
#  1   pubdatetime     datetime64[ns]
#  2   latitude        float64
#  3   longitude       float64
#  4   sumdid          object
#  5   chargelevel     float64
#  6   companyname     int64
#  7   dates           object
#  8   times           object
#  9   hours           int64
#  10  latmovement     float64
#  11  lonmovement     float64
#  12  timeshift       float64
#  13  duration        int64
#  14  cumulative_sum  int64
# dtypes: datetime64[ns](1), float64(6), int64(5), object(3)
# memory usage: 286.6+ MB
