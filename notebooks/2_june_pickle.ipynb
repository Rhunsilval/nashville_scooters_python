# %%
import pandas as pd
import pickle

# %%
# %%time
june = pd.read_csv('../data/june.csv')
june.head()
# Out:
# Wall time: 1min 2s
#            pubdatetime  latitude  longitude  \
# 0  2019-06-01 00:00:12   36.1202   -86.7534
# 1  2019-06-01 00:00:12   36.1630   -86.7765
# 2  2019-06-01 00:00:12   36.1202   -86.7533
# 3  2019-06-01 00:00:12   36.1201   -86.7530
# 4  2019-06-01 00:00:12   36.1622   -86.7806
#
#                                         sumdid sumdtype  chargelevel  \
# 0  Powered93627c35-0f62-5b81-a78d-75a4a92ecf47  Powered         90.0
# 1  Powered17715097-e8a0-5494-a5ab-9b625796607d  Powered         63.0
# 2  Powerede5cb95ae-b091-5a93-86fa-ededd946d0d7  Powered         77.0
# 3  Powered71fa5e4f-1e17-54c4-936d-330df38cc2fa  Powered          0.0
# 4  Poweredfa549dd6-40bb-5757-ac87-2c2528f2bc68  Powered          2.0
#
#   sumdgroup  costpermin companyname
# 0   scooter        0.06        Jump
# 1   scooter        0.06        Jump
# 2   scooter        0.06        Jump
# 3   scooter        0.06        Jump
# 4   scooter        0.06        Jump

# %%
june.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28046095 entries, 0 to 28046094
# Data columns (total 9 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  object
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   sumdtype     object
#  5   chargelevel  float64
#  6   sumdgroup    object
#  7   costpermin   float64
#  8   companyname  object
# dtypes: float64(4), object(5)
# memory usage: 1.9+ GB

# %% [markdown]
# #### convert the company name to an integer
# - find the unique company names
# - assign each company an integer (you can use a dictionary for this step)
# - update the `companyname` column to store the integer id for each company

# %%
june.companyname.unique()
# Out:
# array(['Jump', 'Bird', 'Bolt', 'Gotcha', 'Spin', 'Lime', 'Lyft'],
#       dtype=object)

# %%
company_dict = {'Bird':0, 'Lyft': 1, 'Gotcha': 2, 'Lime': 3, 'Spin': 4, 'Jump': 5, 'Bolt': 6}

# %%
june.companyname = june.companyname.replace(company_dict)

# %% [markdown]
# #### next convert `pubdatetime` to a datetime

# %%
june.pubdatetime = pd.to_datetime(june.pubdatetime)
june.head(2)
# Out:
#           pubdatetime  latitude  longitude  \
# 0 2019-06-01 00:00:12   36.1202   -86.7534
# 1 2019-06-01 00:00:12   36.1630   -86.7765
#
#                                         sumdid sumdtype  chargelevel  \
# 0  Powered93627c35-0f62-5b81-a78d-75a4a92ecf47  Powered         90.0
# 1  Powered17715097-e8a0-5494-a5ab-9b625796607d  Powered         63.0
#
#   sumdgroup  costpermin  companyname
# 0   scooter        0.06            5
# 1   scooter        0.06            5

# %% [markdown]
# #### Next remove unneeded data
# #### keep just the scooters

# %%
june.sumdgroup.unique()
# Out:
# array(['scooter', 'Scooter', 'bicycle'], dtype=object)

# %%
june_scooters = june.loc[june.sumdgroup.isin(['scooter', 'Scooter'])]

# %% [markdown]
# #### keep just the columns we want to work with

# %%
june_scooters = june_scooters[['pubdatetime', 'latitude', 'longitude', 'sumdid', 'chargelevel', 'companyname']]

# %% [markdown]
# #### check `.info()` again

# %%
june_scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28037408 entries, 0 to 28046094
# Data columns (total 6 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   pubdatetime  datetime64[ns]
#  1   latitude     float64
#  2   longitude    float64
#  3   sumdid       object
#  4   chargelevel  float64
#  5   companyname  int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 1.5+ GB

# %% [markdown]
# #### The only object datatype remaining is sumdid (an alphanumeric unique identifier)
# - time to pickle

# %%
june_scooters.to_pickle("../data/june.pkl")

# %%
# %%time
june = pd.read_pickle("../data/june.pkl")
# Out:
# Wall time: 5.19 s

# %%
june.head(30)
# Out:
#            pubdatetime  latitude  longitude  \
# 0  2019-06-01 00:00:12   36.1202   -86.7534
# 1  2019-06-01 00:00:12   36.1630   -86.7765
# 2  2019-06-01 00:00:12   36.1202   -86.7533
# 3  2019-06-01 00:00:12   36.1201   -86.7530
# 4  2019-06-01 00:00:12   36.1622   -86.7806
# 5  2019-06-01 00:00:12   36.1554   -86.7808
# 6  2019-06-01 00:00:12   36.1582   -86.7888
# 7  2019-06-01 00:00:12   36.1447   -86.8132
# 8  2019-06-01 00:00:12   36.1432   -86.8146
# 9  2019-06-01 00:00:12   36.1433   -86.7917
# 10 2019-06-01 00:00:12   36.1197   -86.7531
# 11 2019-06-01 00:00:12   36.1198   -86.7535
# 12 2019-06-01 00:00:12   36.1584   -86.7905
# 13 2019-06-01 00:00:12   36.1540   -86.7858
# 14 2019-06-01 00:00:12   36.1630   -86.7749
# 15 2019-06-01 00:00:12   36.1198   -86.7537
# 16 2019-06-01 00:00:12   36.1202   -86.7533
# 17 2019-06-01 00:00:12   36.1199   -86.7532
# 18 2019-06-01 00:00:12   36.1523   -86.7947
# 19 2019-06-01 00:00:12   36.1200   -86.7529
# 20 2019-06-01 00:00:12   36.1202   -86.7534
# 21 2019-06-01 00:00:12   36.1510   -86.7845
# 22 2019-06-01 00:00:12   36.1638   -86.7800
# 23 2019-06-01 00:00:12   36.1198   -86.7532
# 24 2019-06-01 00:00:12   36.1672   -86.7641
# 25 2019-06-01 00:00:12   36.1203   -86.7536
# 26 2019-06-01 00:00:12   36.1594   -86.7810
# 27 2019-06-01 00:00:12   36.1659   -86.7690
# 28 2019-06-01 00:00:12   36.1203   -86.7533
# 29 2019-06-01 00:00:12   36.1199   -86.7531
#
